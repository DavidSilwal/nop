# %%
import pandas as pd
import pyodbc

# %%
sql_conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server}; SERVER=(localdb)\mssqllocaldb; DATABASE=NorthwindTraders;   Trusted_Connection=yes')

# %%
query ="SELECT TOP (1000) * FROM [NorthwindTraders].[dbo].[Orders]"

# %%
df = pd.read_sql(query, sql_conn)

# %%
df.head()
# Out:
#    OrderID CustomerID  EmployeeID  OrderDate RequiredDate ShippedDate  \
# 0        1      QUICK           5 1996-08-05   1996-09-02  1996-08-12
# 1        2      ERNSH           2 1997-12-24   1998-01-21  1998-01-20
# 2        3      HILAA           5 1997-12-25   1998-01-22  1998-01-14
# 3        4      DRACD           8 1997-12-25   1998-01-22  1998-01-05
# 4        5      ISLAT           1 1997-12-26   1998-01-23  1998-01-05
#
#    ShipVia  Freight                  ShipName  \
# 0        1    76.07                QUICK-Stop
# 1        2   126.66              Ernst Handel
# 2        3    26.52          HILARION-Abastos
# 3        2    33.35  Drachenblut Delikatessen
# 4        3     2.33            Island Trading
#
#                                   ShipAddress       ShipCity     ShipRegion  \
# 0                            Taucherstraße 10      Cunewalde
# 1                                Kirchgasse 6           Graz
# ...

# %% [raw]
# df.describe()

# %%
df.to_csv('NTC.csv', encoding='utf-8', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-bb71f1ba2871> in <module>
# ----> 1 df = pd.read_csv("./data.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...
